# %%
import numpy as np
import cv2
from matplotlib import pyplot as plt

# %%
img = cv2.imread('train/AAA.png', 1) 
type(img)
# Out:
# numpy.ndarray

# %%
# cv2.imshow('image', img)
plt.imshow(img)

# %%
img.shape
# Out:
# (150, 600, 3)

# %%
r = img[0][0][0]
g= img[0][0][1]
b= img[0][0][2]
print(r)
print(g)
print(b)
# Out:
# 242
# 179
# 255

# %%
for i in range(150) :
    for j in range(600) :
        if img[i][j][0] == r and img[i][j][1] == g and img[i][j][2] == b :
            img[i][j][0] = 255
            img[i][j][1] = 255
            img[i][j][2] = 255
            print(img[i][j][0])
            print(img[i][j][1])
            print(img[i][j][2])
# Out:
# 255
# 255
# 255
# 255
# 255
# 255
# 255
# 255
# 255
# 255
# 255
# 255
# 255
# 255
# 255
# 255
# 255
# 255
# 255
# 255
# 255
# 255
# 255
# 255
# 255
# 255
# 255
# 255
# 255
# 255
# 255
# 255
# 255
# 255
# 255
# 255
# 255
# 255
# 255
# 255
# 255
# 255
# 255
# 255
# 255
# 255
# 255
# 255
# 255
# 255
# 255
# 255
# 255
# 255
# 255
# 255
# 255
# 255
# 255
# 255
# 255
# 255
# 255
# 255
# 255
# 255
# 255
# 255
# 255
# 255
# 255
# 255
# 255
# 255
# 255
# 255
# 255
# 255
# 255
# 255
# 255
# 255
# 255
# 255
# 255
# 255
# 255
# 255
# 255
# 255
# 255
# 255
# 255
# 255
# 255
# 255
# 255
# 255
# 255
# 255
# 255
# 255
# 255
# 255
# 255
# 255
# 255
# 255
# 255
# 255
# 255
# 255
# 255
# 255
# 255
# 255
# 255
# 255
# 255
# 255
# 255
# 255
# 255
# 255
# 255
# 255
# 255
# 255
# 255
# 255
# 255
# 255
# 255
# 255
# 255
# 255
# 255
# 255
# 255
# 255
# 255
# 255
# 255
# 255
# 255
# 255
# 255
# 255
# 255
# 255
# 255
# 255
# 255
# 255
# 255
# 255
# 255
# 255
# 255
# 255
# 255
# 255
# 255
# 255
# 255
# 255
# ...

# %%
print(img[0][0][0])
# Out:
# 255

# %%
plt.imshow(img)
